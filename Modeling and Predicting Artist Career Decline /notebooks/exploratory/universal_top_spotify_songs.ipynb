# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', 50)
sns.set_theme(style='whitegrid')

# this is the largest dataset - 2 million rows of daily chart data
# across 73 countries from 2023 to 2025
# it is very large so it may take a moment to load
df_charts = pd.read_csv('/Users/kultumlhabaik/Documents/data-mining-final-project/data/raw/universal_top_spotify_songs.csv')

print('Rows:', len(df_charts))
print('Columns:', df_charts.shape[1])
df_charts.head()
# Out:
# Rows: 2110316
# Columns: 25
#                spotify_id                name                artists  \
# 0  2RkZ5LkEzeHGRsmDqKwmaJ            Ordinary            Alex Warren
# 1  42UBPzRMh5yyz0EDPr6fr1            Manchild      Sabrina Carpenter
# 2  0FTmksd2dxiE5e3rWyJXs6     back to friends                  sombr
# 3  7so0lgd0zP2Sbgs2d7a1SZ    Die With A Smile  Lady Gaga, Bruno Mars
# 4  6dOtVTDdiauQNBQEDOtlAB  BIRDS OF A FEATHER          Billie Eilish
#
#    daily_rank  daily_movement  weekly_movement country snapshot_date  \
# 0           1               1                0     NaN    2025-06-11
# 1           2              -1               48     NaN    2025-06-11
# 2           3               0                1     NaN    2025-06-11
# 3           4               0               -1     NaN    2025-06-11
# 4           5               1                0     NaN    2025-06-11
#
#    popularity  is_explicit  duration_ms                          album_name  \
# ...

# %%
# check date range, countries, and missing values
print('Date Range')
print('Earliest date:', df_charts['snapshot_date'].min())
print('Latest date:  ', df_charts['snapshot_date'].max())

print('\nCountries')
print('Number of countries:', df_charts['country'].nunique())
print('Global chart rather than any specific country: ', df_charts['country'].isnull().sum())

print('\nMissing Values')
missing = df_charts.isnull().sum()
print(missing[missing > 0])
# Out:
# Date Range
# Earliest date: 2023-10-18
# Latest date:   2025-06-11
#
# Countries
# Number of countries: 72
# Global chart rather than any specific country:  28908
#
# Missing Values
# name                     30
# artists                  29
# country               28908
# album_name              822
# album_release_date      659
# dtype: int64

# %% [markdown]
# ## universal_top_spotify_songs.csv — Decision
#
# This dataset covers daily Spotify charts from 2023-10-18 to 2025-06-11
# across 72 countries with 2,110,316 rows.
#
# It cannot be used in this project for one critical reason:
# Our main dataset covers 1990-2020 and this dataset starts in 2023.
# There overlap between them, so it cannot be used
# to help our artist trajectory analysis.
#
# Final decision: This dataset will not be used.
